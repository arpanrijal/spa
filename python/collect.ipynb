# %%
pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: beautifulsoup4 in d:\spa\python\venv\lib\site-packages (from bs4) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\spa\python\venv\lib\site-packages (from beautifulsoup4->bs4) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\spa\python\venv\lib\site-packages (from beautifulsoup4->bs4) (4.15.0)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: D:\spa\python\venv\Scripts\python.exe -m pip install --upgrade pip

# %%
pip install panda
# Out:
# Collecting panda
#   Downloading panda-0.3.1.tar.gz (5.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: setuptools in d:\spa\python\venv\lib\site-packages (from panda) (65.5.0)
# Requirement already satisfied: requests in d:\spa\python\venv\lib\site-packages (from panda) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\spa\python\venv\lib\site-packages (from requests->panda) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\spa\python\venv\lib\site-packages (from requests->panda) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\spa\python\venv\lib\site-packages (from requests->panda) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\spa\python\venv\lib\site-packages (from requests->panda) (2025.11.12)
# Building wheels for collected packages: panda
#   Building wheel for panda (setup.py): started
#   Building wheel for panda (setup.py): finished with status 'done'
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7245 sha256=cf0cbcf362abe11acedf463c58722e010354e4b7bcceee341815d6c9d4d53504
#   Stored in directory: c:\users\arpan\appdata\local\pip\cache\wheels\89\6f\a9\ac355d995bfc97c3e5ed1b0616e5693005a31d13514b6cb8d5
# Successfully built panda
# Installing collected packages: panda
# Successfully installed panda-0.3.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: D:\spa\python\venv\Scripts\python.exe -m pip install --upgrade pip

# %%
from bs4 import BeautifulSoup
import pandas as pd
import os

d = {'S.N.': [], 'Date': [], 'Open': [], 'High': [], 'Low': [], 'Ltp': [], '% Change': [], 'Qty': [], 'Turnover': []}
file = "crest" + ".html"
# for file in os.listdir("STOCKNEPSE"):
try:
    with open(f"STOCKNEPSE/webScraphtmlfiles/{file}", encoding="utf-8") as f:
        html_doc = f.read()
    
    soup = BeautifulSoup(html_doc, 'html.parser')        
    rows = soup.find('tbody').find_all('tr')
    
    for row in rows:
        cols = row.find_all('td')
        
        if len(cols) >= 9:
            d['S.N.'].append(cols[0].get_text().strip())
            d['Date'].append(cols[1].get_text().strip())
            d['Open'].append(cols[2].get_text().strip())
            d['High'].append(cols[3].get_text().strip())
            d['Low'].append(cols[4].get_text().strip())
            d['Ltp'].append(cols[5].get_text().strip())
            d['% Change'].append(cols[6].get_text().strip())
            d['Qty'].append(cols[7].get_text().strip())
            d['Turnover'].append(cols[8].get_text().strip())
    
    print(f"{file}: {len(rows)} rows")
    
except Exception as e:
    print(f"{e}")
csv_filename = file.replace('.html', '.csv')
df = pd.DataFrame(data=d)
df.to_csv(f"STOCKNEPSE/NEPSEDATA/{csv_filename}", index=False)
# Out:
# crest.html: 172 rows
