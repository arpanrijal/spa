# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in d:\vs code for code\spa\python\venv\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in d:\vs code for code\spa\python\venv\lib\site-packages (from bs4) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\vs code for code\spa\python\venv\lib\site-packages (from beautifulsoup4->bs4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\vs code for code\spa\python\venv\lib\site-packages (from beautifulsoup4->bs4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
pip install panda
# Out:
# Requirement already satisfied: panda in d:\vs code for code\spa\python\venv\lib\site-packages (0.3.1)
# Requirement already satisfied: setuptools in d:\vs code for code\spa\python\venv\lib\site-packages (from panda) (65.5.0)
# Requirement already satisfied: requests in d:\vs code for code\spa\python\venv\lib\site-packages (from panda) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\vs code for code\spa\python\venv\lib\site-packages (from requests->panda) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\vs code for code\spa\python\venv\lib\site-packages (from requests->panda) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\vs code for code\spa\python\venv\lib\site-packages (from requests->panda) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\vs code for code\spa\python\venv\lib\site-packages (from requests->panda) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import os

d = {'S.N.': [], 'Date': [], 'Open': [], 'High': [], 'Low': [], 'Close': [], '% Change': [], 'Qty': [], 'Turnover': []}
file = "adbl" + ".html"
# for file in os.listdir("STOCKNEPSE"):
try:
    with open(f"STOCKNEPSE/webScraphtmlfiles/{file}", encoding="utf-8") as f:
        html_doc = f.read()
    
    soup = BeautifulSoup(html_doc, 'html.parser')        
    rows = soup.find('tbody').find_all('tr')
    
    for row in rows:
        cols = row.find_all('td')
        
        if len(cols) >= 9:
            d['S.N.'].append(cols[0].get_text().strip())
            d['Date'].append(cols[1].get_text().strip())
            d['Open'].append(cols[2].get_text().strip())
            d['High'].append(cols[3].get_text().strip())
            d['Low'].append(cols[4].get_text().strip())
            d['Close'].append(cols[5].get_text().strip())
            d['% Change'].append(cols[6].get_text().strip())
            d['Qty'].append(cols[7].get_text().strip())
            d['Turnover'].append(cols[8].get_text().strip())
    
    print(f"{file}: {len(rows)} rows")
    
except Exception as e:
    print(f"{e}")
csv_filename = file.replace('.html', '.csv')
df = pd.DataFrame(data=d)
df.to_csv(f"STOCKNEPSE/NEPSEDATA/{csv_filename}", index=False)
# Out:
# adbl.html: 3516 rows
