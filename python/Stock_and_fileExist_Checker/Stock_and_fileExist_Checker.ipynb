# %%
import pandas as pd
import os

# %%
filepath = f"../DATA-HTML-STOCK/NEPSECompany/NEPSECompanyExtractor.csv"
df = pd.read_csv(filepath)
symbols = df['Symbol']
stock_no_html = []
stock_no_csv = []

for symbol in symbols:
    savepath_html = f"../DATA-HTML-STOCK/webScrapped-htmlfiles/NEPSE-StockWebScrap/{symbol}.html"
    savepath_csv = f"../DATA-HTML-STOCK/NEPSEDATA/{symbol}.csv"
    if not os.path.exists(savepath_html):
        
        print(f"{symbol} html file not exist")
        stock_no_html.append(symbol)
        
        if not os.path.exists(savepath_csv):
            print(f"{symbol} csv file not exist")
            stock_no_csv.append(symbol)
        else:
            print(f"{symbol} csv file exist")
    

print(f"stock_no_html: {stock_no_html}")
print(f"stock_no_csv: {stock_no_csv}")
# Out:
# CORBLP html file not exist
# CORBLP csv file exist
# LFCPO html file not exist
# LFCPO csv file exist
# NMLBS html file not exist
# NMLBS csv file exist
# SBIPO html file not exist
# SBIPO csv file exist
# AMFIPO html file not exist
# AMFIPO csv file exist
# GABLPO html file not exist
# GABLPO csv file exist
# ILFCPO html file not exist
# ILFCPO csv file exist
# stock_no_html: ['CORBLP', 'LFCPO', 'NMLBS', 'SBIPO', 'AMFIPO', 'GABLPO', 'ILFCPO']
# stock_no_csv: []
