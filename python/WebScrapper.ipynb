# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
df = pd.read_csv("STOCKNEPSE/NEPSECompany/NEPSECompanyExtractor.csv")

symbols = df['Symbol'].tolist()

print(f"Found {len(symbols)} companies to scrape")

driver = webdriver.Edge()
driver.set_page_load_timeout(6)

query = "adbl"

try:
    driver.get(f"https://www.sharesansar.com/company/{query}")
except:
    pass

time.sleep(1)

driver.find_element(By.LINK_TEXT, "Price History").click()
time.sleep(3)

all_rows = []
page = 1

while True:
    print(f"Page {page}...", end=" ")
    
    rows = driver.find_elements(By.CSS_SELECTOR, "#myTableCPriceHistory tbody tr")
    
    for row in rows:
        all_rows.append(row.get_attribute('outerHTML'))
    # ["<tr>row1</tr>", "<tr>row2</tr>", "<tr>row3</tr>"]
    print(f"✓ {len(rows)} rows")
    
    next_button = driver.find_element(By.ID, "myTableCPriceHistory_next")
    if "disabled" in next_button.get_attribute("class"):
        break
    
    next_button.click()
    time.sleep(2)
    page += 1

html_content = f'''<table id="myTableCPriceHistory">
<tbody>
{''.join(all_rows)} # Output: <tr>row1</tr><tr>row2</tr><tr>row3</tr>
</tbody>
</table>'''

with open(f'STOCKNEPSE/webScraphtmlfiles/{query}.html', 'w', encoding='utf-8') as f:
    f.write(html_content)

print(f"\n✓ Done! {len(all_rows)} rows saved to HTML")
driver.close()
# Out:
# Found 300 companies to scrape
# Page 1... ✓ 20 rows
# Page 2... ✓ 20 rows
# Page 3... ✓ 20 rows
# Page 4... ✓ 20 rows
# Page 5... ✓ 20 rows
# Page 6... ✓ 20 rows
# Page 7... ✓ 20 rows
# Page 8... ✓ 20 rows
# Page 9... ✓ 20 rows
# Page 10... ✓ 20 rows
# Page 11... ✓ 20 rows
# Page 12... ✓ 20 rows
# Page 13... ✓ 20 rows
# Page 14... ✓ 20 rows
# Page 15... ✓ 20 rows
# Page 16... ✓ 20 rows
# Page 17... ✓ 20 rows
# Page 18... ✓ 20 rows
# Page 19... ✓ 20 rows
# Page 20... ✓ 20 rows
# Page 21... ✓ 20 rows
# Page 22... ✓ 20 rows
# Page 23... ✓ 20 rows
# Page 24... ✓ 20 rows
# Page 25... ✓ 20 rows
# Page 26... ✓ 20 rows
# Page 27... ✓ 20 rows
# Page 28... ✓ 20 rows
# Page 29... ✓ 20 rows
# Page 30... ✓ 20 rows
# Page 31... ✓ 20 rows
# Page 32... ✓ 20 rows
# Page 33... ✓ 20 rows
# Page 34... ✓ 20 rows
# Page 35... ✓ 20 rows
# Page 36... ✓ 20 rows
# Page 37... ✓ 20 rows
# Page 38... ✓ 20 rows
# Page 39... ✓ 20 rows
# Page 40... ✓ 20 rows
# Page 41... ✓ 20 rows
# Page 42... ✓ 20 rows
# ...

# %%
# # Load the CSV with company symbols
# df = pd.read_csv("STOCKNEPSE/NEPSECompany/NEPSECompanyExtractor.csv")

# # Get list of symbols
# symbols = df['Symbol'].tolist()

# print(f"Found {len(symbols)} companies to scrape")

# driver = webdriver.Edge()
# driver.set_page_load_timeout(6)

# for query in symbols:
#     print(f"\n{'='*50}")
#     print(f"Scraping: {query}")
#     print(f"{'='*50}")
    
#     try:
#         driver.get(f"https://www.sharesansar.com/company/{query}")
#     except:
#         pass
    
#     time.sleep(1)
    
#     try:
#         driver.find_element(By.LINK_TEXT, "Price History").click()
#         time.sleep(3)
        
#         all_rows = []
#         page = 1
        
#         while True:
#             print(f"Page {page}...", end=" ")
            
#             rows = driver.find_elements(By.CSS_SELECTOR, "#myTableCPriceHistory tbody tr")
            
#             for row in rows:
#                 all_rows.append(row.get_attribute('outerHTML'))
            
#             print(f"✓ {len(rows)} rows")
            
#             next_button = driver.find_element(By.ID, "myTableCPriceHistory_next")
#             if "disabled" in next_button.get_attribute("class"):
#                 break
            
#             next_button.click()
#             time.sleep(2)
#             page += 1
        
#         html_content = f'''<table id="myTableCPriceHistory">
# <tbody>
# {''.join(all_rows)}
# </tbody>
# </table>'''
        
#         with open(f'STOCKNEPSE/webScraphtmlfiles/{query}.html', 'w', encoding='utf-8') as f:
#             f.write(html_content)
        
#         print(f"✓ {query}: {len(all_rows)} total rows saved")
        
#     except Exception as e:
#         print(f"✗ Error with {query}: {e}")
#         continue

# driver.close()
# print("\n✓ All companies scraped!")
# Out:
# ✗ Error with GABL: Message: invalid session id; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff7bda65085
# 	0x7ff7bda650e4
# 	0x7ff7bd7bdf2e
# 	0x7ff7bd7fb5e5
# 	0x7ff7bd827452
# 	0x7ff7bd7b5a41
# 	0x7ff7bd823df2
# 	0x7ff7bd823667
# 	0x7ff7bd7965c5
# 	0x7ff7bd8c0214
# 	0x7ff7bd8bc685
# 	0x7ff7bd8cce73
# 	0x7ff7bda803b8
# 	0x7ff7bda88c86
# 	0x7ff7bd794f12
# 	0x7ff7bdbdd6f8
# 	0x7ffb7486e8d7
# 	0x7ffb765ec53c
#
#
# ...
# Scraping: GBIME
# ...
# ✗ Error with GBIME: Message: invalid session id; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff7bda65085
# 	0x7ff7bda650e4
# 	0x7ff7bd7bdf2e
# 	0x7ff7bd7fb5e5
# 	0x7ff7bd827452
# 	0x7ff7bd7b5a41
# ...
